# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.133 🚀 Python-3.9.22 torch-2.7.0+cu126 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20020MiB)
# Setup complete ✅ (20 CPUs, 62.5 GB RAM, 299.8/465.4 GB disk)

# %%
# !yolo train model=yolo_models/yolo11n.pt data=../CDFSOD-benchmark/datasets/10shot/zoomed_mixed/data.yaml epochs=25 imgsz=640 batch=64
# Out:
# New https://pypi.org/project/ultralytics/8.3.136 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.133 🚀 Python-3.9.22 torch-2.7.0+cu126 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20020MiB)
# ...

# %%
# !yolo detect val model=runs/detect/train11/weights/best.pt data=../CDFSOD-benchmark/datasets/generated/turbo_large/trucks_cropped_new/data.yaml split=test
# Out:
# Ultralytics 8.3.133 🚀 Python-3.9.22 torch-2.7.0+cu126 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20020MiB)
# YOLO11n summary (fused): 100 layers, 2,584,297 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5685.4±1172.4 MB/s, size: 59.9 KB)
# val: Scanning /home/a519359/CDFSOD-benchmark/datasets/zoomed_real/test/labels.ca
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         20        165     0.0536      0.118     0.0548     0.0448
#         flat-light-bar          5          5          0          0          0          0
#       front-attachment          3          3      0.286      0.667      0.348        0.3
#            front-fence          2          2          0          0          0          0
#                   horn         12         24     0.0178      0.125     0.0102    0.00308
#                light-1         11         56      0.263      0.446      0.233      0.188
# ...

# %%
# !zip -r /content/runs/detect/yolo11n_truck_cabin.zip /content/runs/detect/train2
# Out:
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/train_batch690.jpg (deflated 6%)
#   adding: content/runs/detect/train2/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 37%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 20%)
#   adding: content/runs/detect/train2/train_batch691.jpg (deflated 9%)
#   adding: content/runs/detect/train2/events.out.tfevents.1744019775.b1a69c8958e9.3276.0 (deflated 92%)
#   adding: content/runs/detect/train2/val_batch1_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 10%)
# ...

# %%
# !yolo export model=truck_cabin.pt format=tflite
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'truck_cabin.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744102359.242133    3066 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744102359.306324    3066 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.31', 'tflite_support', 'onnxruntime'] not found, attempting AutoUpdate...
# ...

# %%
# !zip -r /content/yolo11n_truck_cabin_tflite.zip /content/truck_cabin_saved_model
# Out:
#   adding: content/truck_cabin_saved_model/ (stored 0%)
#   adding: content/truck_cabin_saved_model/saved_model.pb (deflated 17%)
#   adding: content/truck_cabin_saved_model/variables/ (stored 0%)
#   adding: content/truck_cabin_saved_model/variables/variables.data-00000-of-00001 (deflated 87%)
#   adding: content/truck_cabin_saved_model/variables/variables.index (deflated 33%)
#   adding: content/truck_cabin_saved_model/metadata.yaml (deflated 35%)
#   adding: content/truck_cabin_saved_model/fingerprint.pb (stored 0%)
#   adding: content/truck_cabin_saved_model/assets/ (stored 0%)
#   adding: content/truck_cabin_saved_model/truck_cabin_float16.tflite (deflated 11%)
#   adding: content/truck_cabin_saved_model/truck_cabin_float32.tflite (deflated 14%)
